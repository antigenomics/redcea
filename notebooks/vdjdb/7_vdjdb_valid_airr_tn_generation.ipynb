# %% [markdown]
# # VDJdb_valid: AIRR-format эпитопы + True-Negative клонотипы
#
# Этот ноутбук:
# 1. Читает сырой VDJdb (TSV).
# 2. Находит топ-20 эпитопов отдельно для TRA и TRB (по числу уникальных клонотипов).
# 3. Приводит записи к минимальному AIRR-like формату: `clone_id, junction_aa, v_call, j_call, locus`.
# 4. Для каждого эпитопа добавляет true-negative (TN) клонотипы: 10% и 25% (сэмплируются из VDJdb той же цепи после исключения текущего эпитопа).
#    TN дописываются в конец файла и получают `clone_id`, начиная с 2000.
# 5. Делает укороченные background-файлы: первые 100 000 строк для `tra_background.tsv` и `trb_background.tsv`.
#
# Результаты сохраняются в: `vdjdb_valid/airr_format/`.

# %%
# =========================
# params
# =========================
from pathlib import Path

# 1) Сырой VDJdb (tsv)
RAW_VDJDB_TSV = Path("/projects/immunestatus/vdjdb/vdjdb-2025-07-30/vdjdb_full_filtered.txt")

# 2) (опционально) директория, где уже лежат background файлы в AIRR-формате
AIRR_FORMAT_DIR = Path("/projects/immunestatus/vdjdb/airr_format")  # где лежат tra_background.tsv / trb_background.tsv

# 3) куда писать результаты
OUT_ROOT = Path("/projects/immunestatus/vdjdb_valid")
OUT_AIRR = OUT_ROOT / "airr_format"
OUT_AIRR.mkdir(parents=True, exist_ok=True)

TOP_N_EPITOPES = 20
TN_PCTS = [0.10, 0.25]     # 10% и 25%
TN_CLONE_ID_START = 200000   # начиная с 2000

RANDOM_SEED = 42

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 140)

rng = np.random.default_rng(RANDOM_SEED)

# %% [markdown]
# ## Загрузка VDJdb и авто-детект колонок
#
# Ноутбук старается автоматически найти нужные поля (цепь, эпитоп, CDR3aa, V, J).
# Если авто-детект не сработает — ниже есть `detected_cols`, и можно вручную поправить переменные.

# %%
raw = pd.read_csv(RAW_VDJDB_TSV, sep="\t", low_memory=False)
raw.columns = [c.replace(".", "_") for c in raw.columns]  # на всякий случай
raw.head()
# Out:
#   cdr3_alpha v_alpha j_alpha      cdr3_beta     v_beta d_beta      j_beta      species        mhc_a mhc_b mhc_class antigen_epitope  \
# 0        NaN     NaN     NaN  CASSIVGGNEQFF  TRBV19*01    NaN  TRBJ2-1*01  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL
# 1        NaN     NaN     NaN  CASSMRSTGELFF  TRBV19*01    NaN  TRBJ2-2*01  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL
# 2        NaN     NaN     NaN  CASSIRSAWAQYF  TRBV19*01    NaN  TRBJ2-3*01  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL
# 3        NaN     NaN     NaN  CASSQRSTGELFF  TRBV19*01    NaN  TRBJ2-2*01  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL
# 4        NaN     NaN     NaN  CASSIRSSYEQYF  TRBV19*01    NaN  TRBJ2-7*01  HomoSapiens  HLA-A*02:01   B2M      MHCI       GILGFVFTL
#
#   antigen_gene antigen_species   reference_id method_identification method_frequency method_singlecell method_sequencing  \
# 0            M      InfluenzaA  PMID:28629751        tetramer-sort             70.5%               NaN      amplicon-seq
# 1            M      InfluenzaA  PMID:28629751        tetramer-sort             11.0%               NaN      amplicon-seq
# 2            M      InfluenzaA  PMID:28629751        tetramer-sort              1.9%               NaN      amplicon-seq
# 3            M      InfluenzaA  PMID:28629751        tetramer-sort              1.7%               NaN      amplicon-seq
# 4            M      InfluenzaA  PMID:28629751        tetramer-sort              0.9%               NaN      amplicon-seq
#
#                                  method_verification meta_study_id meta_cell_subset meta_subject_cohort meta_subject_id meta_replica_id  \
# 0  antigen-loaded-targets,antigen-expressing-targets           NaN             CD8+           MA-EBV-SN          donor1             NaN
# 1  antigen-loaded-targets,antigen-expressing-targets           NaN             CD8+           MA-EBV-SN          donor1             NaN
# 2  antigen-loaded-targets,antigen-expressing-targets           NaN             CD8+    MA-EBV-SN IAV-M1          donor1             NaN
# 3  antigen-loaded-targets,antigen-expressing-targets           NaN             CD8+    MA-EBV-SN IAV-M1          donor1             NaN
# 4  antigen-loaded-targets,antigen-expressing-targets           NaN             CD8+    MA-EBV-SN IAV-M1          donor1             NaN
#
#   meta_clone_id meta_epitope_id meta_tissue           meta_donor_MHC meta_donor_MHC_method meta_structure_id cdr3fix_alpha  \
# 0           NaN         M158–66        PBMC  A02,A03,B07,B27,C01,C07                   NaN               NaN           NaN
# 1           NaN         M158–66        PBMC  A02,A03,B07,B27,C01,C07                   NaN               NaN           NaN
# 2           NaN         M158–66        PBMC  A02,A03,B07,B27,C01,C07                   NaN               NaN           NaN
# 3           NaN         M158–66        PBMC  A02,A03,B07,B27,C01,C07                   NaN               NaN           NaN
# 4           NaN         M158–66        PBMC  A02,A03,B07,B27,C01,C07                   NaN               NaN           NaN
#
#                                         cdr3fix_beta  vdjdb_score
# 0  {'cdr3': 'CASSIVGGNEQFF', 'cdr3_old': 'CASSIVG...            3
# 1  {'cdr3': 'CASSMRSTGELFF', 'cdr3_old': 'CASSMRS...            3
# 2  {'cdr3': 'CASSIRSAWAQYF', 'cdr3_old': 'CASSIRS...            2
# 3  {'cdr3': 'CASSQRSTGELFF', 'cdr3_old': 'CASSQRS...            2
# 4  {'cdr3': 'CASSIRSSYEQYF', 'cdr3_old': 'CASSIRS...            3

# %%
VDJDB_COLS = {
    "epitope": "antigen_epitope",

    "TRA": {"cdr3": "cdr3_alpha", "v": "v_alpha", "j": "j_alpha"},
    "TRB": {"cdr3": "cdr3_beta",  "v": "v_beta",  "j": "j_beta"},
}

# %%
def to_airr_like(df: pd.DataFrame, chain: str) -> pd.DataFrame:
    """
    chain: 'TRA' or 'TRB'
    """
    chain = chain.upper()
    assert chain in ("TRA", "TRB")

    cols = VDJDB_COLS[chain]
    ep_col = VDJDB_COLS["epitope"]

    # фильтр: берем только строки где нужная цепь реально есть
    m = df[cols["cdr3"]].notna()
    sub = df.loc[m, [cols["cdr3"], cols["v"], cols["j"], ep_col]].copy()

    # минимальный AIRR-like
    out = pd.DataFrame({
        "clone_id": sub.index,
        "junction_aa": sub[cols["cdr3"]].astype(str),
        "v_call": sub[cols["v"]].astype(str),
        "j_call": sub[cols["j"]].astype(str),
        "locus": "alpha" if chain == "TRA" else "beta",
        "antigen_epitope": sub[ep_col].astype(str),
    })

    # при желании можно выкинуть мусорные "nan" строки после astype(str)
    out = out[out["junction_aa"].str.lower() != "nan"].copy()

    return out

# %% [markdown]
# ## Выбор топ-20 эпитопов по TRA и TRB (по числу уникальных клонотипов)

# %%
def top_epitopes(df: pd.DataFrame, chain: str, n: int = 20) -> list[str]:
    chain = chain.upper()
    cols = VDJDB_COLS[chain]
    ep_col = VDJDB_COLS["epitope"]

    m = df[cols["cdr3"]].notna()
    sub = df.loc[m, [ep_col, cols["cdr3"], cols["v"], cols["j"]]].copy()

    sub["key"] = (
        sub[cols["cdr3"]].astype(str) + "|" +
        sub[cols["v"]].astype(str) + "|" +
        sub[cols["j"]].astype(str)
    )

    counts = sub.groupby(ep_col)["key"].nunique().sort_values(ascending=False)
    return counts.head(n).index.tolist()

top_tra = top_epitopes(raw, "TRA", n=20)
top_trb = top_epitopes(raw, "TRB", n=20)

# %% [markdown]
# ## Функции экспорта AIRR-like и генерации TN

# %%
def sample_true_negative(
    df_raw: pd.DataFrame,
    chain: str,
    epitope: str,
    n_pos: int,
    frac: float,
    seed: int = 1,
) -> pd.DataFrame:
    chain = chain.upper()
    cols = VDJDB_COLS[chain]
    ep_col = VDJDB_COLS["epitope"]

    # кандидаты: нужная цепь есть, и это НЕ текущий эпитоп
    m = df_raw[cols["cdr3"]].notna() & (df_raw[ep_col] != epitope)
    cand = df_raw.loc[m].copy()

    # сконвертим кандидатов в AIRR-like
    cand_airr = to_airr_like(cand, chain)

    # сколько TN надо
    n_tn = int(round(frac * n_pos))
    n_tn = min(n_tn, len(cand_airr))
    tn = cand_airr.sample(n=n_tn, random_state=seed).copy()

    # новые id с 2000
    tn["clone_id"] = np.arange(TN_CLONE_ID_START, TN_CLONE_ID_START + len(tn), dtype=int)
    return tn

# %% [markdown]
# ## Генерация файлов по эпитопам (TRA/TRB) + TN10/TN25
#
# Для каждого эпитопа сохраняем 4 файла:
# - `*_tn10.tsv` и `*_tn25.tsv` — полный
# - `*_uni_tn10.tsv` и `*_uni_tn25.tsv` — уникализированный
#
# Плюс файлы меток: `*_labels.tsv`.

# %%
from pathlib import Path

OUTDIR = Path("/projects/immunestatus/vdjdb_valid/airr_format")
OUTDIR.mkdir(parents=True, exist_ok=True)

def build_and_save_for_epitope(df_raw: pd.DataFrame, chain: str, epitope: str, seed: int = 1):
    chain = chain.upper()
    ep_col = VDJDB_COLS["epitope"]

    # positive: только этот эпитоп + нужная цепь присутствует
    pos_raw = df_raw[df_raw[ep_col] == epitope].copy()
    pos_airr = to_airr_like(pos_raw, chain)

    # TN (10% / 25% от числа позитивов)
    tn10 = sample_true_negative(df_raw, chain, epitope, n_pos=len(pos_airr), frac=0.10, seed=seed)
    tn25 = sample_true_negative(df_raw, chain, epitope, n_pos=len(pos_airr), frac=0.25, seed=seed)

    # финальные датасеты: pos + tn
    out10 = pd.concat([pos_airr, tn10], ignore_index=True)
    out25 = pd.concat([pos_airr, tn25], ignore_index=True)

    # имена как у тебя принято (можно поправить)
    prefix = "tra" if chain == "TRA" else "trb"

    p10 = OUTDIR / f"{prefix}_vdjdb_{epitope}_tn10.tsv"
    p25 = OUTDIR / f"{prefix}_vdjdb_{epitope}_tn25.tsv"

    out10.to_csv(p10, sep="\t", index=False)
    out25.to_csv(p25, sep="\t", index=False)

    return {
        "epitope": epitope,
        "chain": chain,
        "n_pos": len(pos_airr),
        "n_tn10": len(tn10),
        "n_tn25": len(tn25),
        "path_tn10": str(p10),
        "path_tn25": str(p25),
    }

# %%
summary = []

for ep in top_tra:
    summary.append(build_and_save_for_epitope(raw, "TRA", ep, seed=1))

for ep in top_trb:
    summary.append(build_and_save_for_epitope(raw, "TRB", ep, seed=1))

summary_df = pd.DataFrame(summary)
summary_df
# Out:
#            epitope chain  n_pos  n_tn10  n_tn25                                          path_tn10  \
# 0        KLGGALQAK   TRA  13726    1373    3432  /projects/immunestatus/vdjdb_valid/airr_format...
# 1        GILGFVFTL   TRA   8481     848    2120  /projects/immunestatus/vdjdb_valid/airr_format...
# 2        NLVPMVATV   TRA   2596     260     649  /projects/immunestatus/vdjdb_valid/airr_format...
# 3       AVFDRKSDAK   TRA   1731     173     433  /projects/immunestatus/vdjdb_valid/airr_format...
# 4         RAKFKQLL   TRA   2182     218     546  /projects/immunestatus/vdjdb_valid/airr_format...
# 5        YLQPRTFLL   TRA    849      85     212  /projects/immunestatus/vdjdb_valid/airr_format...
# 6        IVTDFSVIK   TRA    714      71     178  /projects/immunestatus/vdjdb_valid/airr_format...
# 7       LLAGIGTVPI   TRA    643      64     161  /projects/immunestatus/vdjdb_valid/airr_format...
# 8        RLRAEAQVK   TRA    424      42     106  /projects/immunestatus/vdjdb_valid/airr_format...
# 9        GLCTLVAML   TRA   1002     100     250  /projects/immunestatus/vdjdb_valid/airr_format...
# 10       SPRWYFYYL   TRA    393      39      98  /projects/immunestatus/vdjdb_valid/airr_format...
# 11      TTDPSFLGRY   TRA    402      40     100  /projects/immunestatus/vdjdb_valid/airr_format...
# 12       LLLGIGILV   TRA    369      37      92  /projects/immunestatus/vdjdb_valid/airr_format...
# 13      ELAGIGILTV   TRA    389      39      97  /projects/immunestatus/vdjdb_valid/airr_format...
# 14      SSLENFRAYV   TRA    429      43     107  /projects/immunestatus/vdjdb_valid/airr_format...
# 15       LLWNGPMAV   TRA    319      32      80  /projects/immunestatus/vdjdb_valid/airr_format...
# 16       SSYRRPVGI   TRA    640      64     160  /projects/immunestatus/vdjdb_valid/airr_format...
# 17       VMATRRNVL   TRA    255      26      64  /projects/immunestatus/vdjdb_valid/airr_format...
# 18       ASNENMETM   TRA    308      31      77  /projects/immunestatus/vdjdb_valid/airr_format...
# 19       CINGVCWTV   TRA    253      25      63  /projects/immunestatus/vdjdb_valid/airr_format...
# 20       SLLMWITQV   TRB  29699    2970    7425  /projects/immunestatus/vdjdb_valid/airr_format...
# 21       KLGGALQAK   TRB  13726    1373    3432  /projects/immunestatus/vdjdb_valid/airr_format...
# 22       GILGFVFTL   TRB  10681    1068    2670  /projects/immunestatus/vdjdb_valid/airr_format...
# 23       NLVPMVATV   TRB   5088     509    1272  /projects/immunestatus/vdjdb_valid/airr_format...
# 24      AVFDRKSDAK   TRB   1746     175     436  /projects/immunestatus/vdjdb_valid/airr_format...
# 25      ELAGIGILTV   TRB   2268     227     567  /projects/immunestatus/vdjdb_valid/airr_format...
# 26        RAKFKQLL   TRB   2897     290     724  /projects/immunestatus/vdjdb_valid/airr_format...
# 27       GLCTLVAML   TRB   3211     321     803  /projects/immunestatus/vdjdb_valid/airr_format...
# 28       YLQPRTFLL   TRB   1081     108     270  /projects/immunestatus/vdjdb_valid/airr_format...
# 29      LLAGIGTVPI   TRB    843      84     211  /projects/immunestatus/vdjdb_valid/airr_format...
# 30       IVTDFSVIK   TRB    742      74     186  /projects/immunestatus/vdjdb_valid/airr_format...
# 31       CTPYDINQM   TRB    685      68     171  /projects/immunestatus/vdjdb_valid/airr_format...
# 32        TTPESANL   TRB    659      66     165  /projects/immunestatus/vdjdb_valid/airr_format...
# 33       SPRWYFYYL   TRB    535      54     134  /projects/immunestatus/vdjdb_valid/airr_format...
# 34      KRWIILGLNK   TRB    578      58     144  /projects/immunestatus/vdjdb_valid/airr_format...
# 35  TFEYVSQPFLMDLE   TRB    459      46     115  /projects/immunestatus/vdjdb_valid/airr_format...
# 36       YVLDHLIVV   TRB    872      87     218  /projects/immunestatus/vdjdb_valid/airr_format...
# 37      TTDPSFLGRY   TRB    430      43     108  /projects/immunestatus/vdjdb_valid/airr_format...
# 38       LLWNGPMAV   TRB    445      44     111  /projects/immunestatus/vdjdb_valid/airr_format...
# 39       RLRAEAQVK   TRB    424      42     106  /projects/immunestatus/vdjdb_valid/airr_format...
#
#                                             path_tn25
# 0   /projects/immunestatus/vdjdb_valid/airr_format...
# 1   /projects/immunestatus/vdjdb_valid/airr_format...
# 2   /projects/immunestatus/vdjdb_valid/airr_format...
# 3   /projects/immunestatus/vdjdb_valid/airr_format...
# 4   /projects/immunestatus/vdjdb_valid/airr_format...
# 5   /projects/immunestatus/vdjdb_valid/airr_format...
# 6   /projects/immunestatus/vdjdb_valid/airr_format...
# 7   /projects/immunestatus/vdjdb_valid/airr_format...
# 8   /projects/immunestatus/vdjdb_valid/airr_format...
# 9   /projects/immunestatus/vdjdb_valid/airr_format...
# 10  /projects/immunestatus/vdjdb_valid/airr_format...
# 11  /projects/immunestatus/vdjdb_valid/airr_format...
# 12  /projects/immunestatus/vdjdb_valid/airr_format...
# 13  /projects/immunestatus/vdjdb_valid/airr_format...
# 14  /projects/immunestatus/vdjdb_valid/airr_format...
# 15  /projects/immunestatus/vdjdb_valid/airr_format...
# 16  /projects/immunestatus/vdjdb_valid/airr_format...
# 17  /projects/immunestatus/vdjdb_valid/airr_format...
# 18  /projects/immunestatus/vdjdb_valid/airr_format...
# 19  /projects/immunestatus/vdjdb_valid/airr_format...
# 20  /projects/immunestatus/vdjdb_valid/airr_format...
# 21  /projects/immunestatus/vdjdb_valid/airr_format...
# 22  /projects/immunestatus/vdjdb_valid/airr_format...
# 23  /projects/immunestatus/vdjdb_valid/airr_format...
# 24  /projects/immunestatus/vdjdb_valid/airr_format...
# 25  /projects/immunestatus/vdjdb_valid/airr_format...
# 26  /projects/immunestatus/vdjdb_valid/airr_format...
# 27  /projects/immunestatus/vdjdb_valid/airr_format...
# 28  /projects/immunestatus/vdjdb_valid/airr_format...
# 29  /projects/immunestatus/vdjdb_valid/airr_format...
# 30  /projects/immunestatus/vdjdb_valid/airr_format...
# 31  /projects/immunestatus/vdjdb_valid/airr_format...
# 32  /projects/immunestatus/vdjdb_valid/airr_format...
# 33  /projects/immunestatus/vdjdb_valid/airr_format...
# 34  /projects/immunestatus/vdjdb_valid/airr_format...
# 35  /projects/immunestatus/vdjdb_valid/airr_format...
# 36  /projects/immunestatus/vdjdb_valid/airr_format...
# 37  /projects/immunestatus/vdjdb_valid/airr_format...
# 38  /projects/immunestatus/vdjdb_valid/airr_format...
# 39  /projects/immunestatus/vdjdb_valid/airr_format...

# %% [markdown]
# ## Background: первые 100 000 строк

# %%
def head_100k(in_path: Path, out_path: Path, n: int = 100_000):
    if not in_path.exists():
        raise FileNotFoundError(in_path)
    chunk = pd.read_csv(in_path, sep="\t", nrows=n)
    chunk.to_csv(out_path, sep="\t", index=False)
    return len(chunk)

tra_bg_in = AIRR_FORMAT_DIR / "tra_background.tsv"
trb_bg_in = AIRR_FORMAT_DIR / "trb_background.tsv"

tra_bg_out = OUT_AIRR / "tra_background_100k.tsv"
trb_bg_out = OUT_AIRR / "trb_background_100k.tsv"

n1 = head_100k(tra_bg_in, tra_bg_out, n=100_000)
n2 = head_100k(trb_bg_in, trb_bg_out, n=100_000)

n1, n2, tra_bg_out, trb_bg_out
# Out:
# (100000,
#  100000,
#  PosixPath('/projects/immunestatus/vdjdb_valid/airr_format/tra_background_100k.tsv'),
#  PosixPath('/projects/immunestatus/vdjdb_valid/airr_format/trb_background_100k.tsv'))

# %% [markdown]
# ## Быстрая проверка результатов

# %%
created = sorted([p.name for p in OUT_AIRR.glob("*.tsv")])
print("TSV files:", len(created))
created[:40]
# Out:
# TSV files: 82
# ['tra_background_100k.tsv',
#  'tra_vdjdb_ASNENMETM_tn10.tsv',
#  'tra_vdjdb_ASNENMETM_tn25.tsv',
#  'tra_vdjdb_AVFDRKSDAK_tn10.tsv',
#  'tra_vdjdb_AVFDRKSDAK_tn25.tsv',
#  'tra_vdjdb_CINGVCWTV_tn10.tsv',
#  'tra_vdjdb_CINGVCWTV_tn25.tsv',
#  'tra_vdjdb_ELAGIGILTV_tn10.tsv',
#  'tra_vdjdb_ELAGIGILTV_tn25.tsv',
#  'tra_vdjdb_GILGFVFTL_tn10.tsv',
#  'tra_vdjdb_GILGFVFTL_tn25.tsv',
#  'tra_vdjdb_GLCTLVAML_tn10.tsv',
#  'tra_vdjdb_GLCTLVAML_tn25.tsv',
#  'tra_vdjdb_IVTDFSVIK_tn10.tsv',
#  'tra_vdjdb_IVTDFSVIK_tn25.tsv',
#  'tra_vdjdb_KLGGALQAK_tn10.tsv',
#  'tra_vdjdb_KLGGALQAK_tn25.tsv',
#  'tra_vdjdb_LLAGIGTVPI_tn10.tsv',
#  'tra_vdjdb_LLAGIGTVPI_tn25.tsv',
#  'tra_vdjdb_LLLGIGILV_tn10.tsv',
#  'tra_vdjdb_LLLGIGILV_tn25.tsv',
#  'tra_vdjdb_LLWNGPMAV_tn10.tsv',
#  'tra_vdjdb_LLWNGPMAV_tn25.tsv',
#  'tra_vdjdb_NLVPMVATV_tn10.tsv',
#  'tra_vdjdb_NLVPMVATV_tn25.tsv',
#  'tra_vdjdb_RAKFKQLL_tn10.tsv',
#  'tra_vdjdb_RAKFKQLL_tn25.tsv',
#  'tra_vdjdb_RLRAEAQVK_tn10.tsv',
#  'tra_vdjdb_RLRAEAQVK_tn25.tsv',
#  'tra_vdjdb_SPRWYFYYL_tn10.tsv',
#  'tra_vdjdb_SPRWYFYYL_tn25.tsv',
#  'tra_vdjdb_SSLENFRAYV_tn10.tsv',
#  'tra_vdjdb_SSLENFRAYV_tn25.tsv',
#  'tra_vdjdb_SSYRRPVGI_tn10.tsv',
#  'tra_vdjdb_SSYRRPVGI_tn25.tsv',
#  'tra_vdjdb_TTDPSFLGRY_tn10.tsv',
#  'tra_vdjdb_TTDPSFLGRY_tn25.tsv',
#  'tra_vdjdb_VMATRRNVL_tn10.tsv',
#  'tra_vdjdb_VMATRRNVL_tn25.tsv',
#  'tra_vdjdb_YLQPRTFLL_tn10.tsv']

# %%
# sanity-check: открыть один файл и убедиться, что TN в конце и clone_id с 2000
example = next(iter(OUT_AIRR.glob("trb_vdjdb_*_tn10.tsv")))
ex = pd.read_csv(example, sep="\t")
print("Example:", example.name)
display(ex.head(3))
display(ex.tail(3))
print("min clone_id:", ex["clone_id"].min(), "max clone_id:", ex["clone_id"].max())
print("TN rows (clone_id>=200000):", (ex["clone_id"]>=TN_CLONE_ID_START).sum())
# Out:
# Example: trb_vdjdb_RLRAEAQVK_tn10.tsv
#    clone_id       junction_aa       v_call      j_call locus antigen_epitope
# 0     36673   CASGGKVFPPYEQYF  TRBV12-5*01  TRBJ2-7*01  beta       RLRAEAQVK
# 1     36893  CASREIQGSGANVLTF   TRBV7-9*01  TRBJ2-6*01  beta       RLRAEAQVK
# 2     36962   CASSQVGRPYNEQFF   TRBV4-3*01  TRBJ2-1*01  beta       RLRAEAQVK
#      clone_id    junction_aa       v_call      j_call locus antigen_epitope
# 463    200039    CASTFGGELFF   TRBV7-9*01  TRBJ2-2*01  beta       KLGGALQAK
# 464    200040  CATSRASTDTQYF  TRBV24-1*01  TRBJ2-3*01  beta       KLGGALQAK
# 465    200041  CASSTRSTHEQYF    TRBV19*01  TRBJ2-7*01  beta       GILGFVFTL
# min clone_id: 36673 max clone_id: 200041
# TN rows (clone_id>=200000): 42
