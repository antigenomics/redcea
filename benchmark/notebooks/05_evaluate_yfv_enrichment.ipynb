# %% [markdown]
# # 05 Evaluate YFV Enrichment
#
# Compute cluster-level sample-vs-background enrichment and donor-level summary metrics.

# %%
from pathlib import Path
import os
import sys

for candidate in [Path.cwd(), *Path.cwd().parents]:
    if (candidate / "benchmark" / "data_sources.py").exists():
        REPO_ROOT = candidate
        break
else:
    raise RuntimeError("Could not find repository root containing benchmark/data_sources.py")

os.chdir(REPO_ROOT)
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))
print(f"Benchmark repo root: {REPO_ROOT}")

# %%
from benchmark import run_yfv_enrichment_evaluation
from benchmark.notebook_displays import show_yfv_enrichment_outputs

enrichment_df, summary_df = run_yfv_enrichment_evaluation()
show_yfv_enrichment_outputs(summary_df, REPO_ROOT)
summary_df.head()
