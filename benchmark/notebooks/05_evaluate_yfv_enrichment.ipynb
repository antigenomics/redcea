# %% [markdown]
# # 05 Evaluate YFV Enrichment
#
# Compute cluster-level sample-vs-background enrichment and donor-level summary metrics.

# %%
from benchmark import run_yfv_enrichment_evaluation

enrichment_df, summary_df = run_yfv_enrichment_evaluation()
summary_df.head()
