# %% [markdown]
# # 08 Summary And Method Selection
#
# Combine the VDJdb and YFV outputs into a single comparison table and write the final benchmark interpretation.

# %%
from benchmark import run_summary_and_method_selection

comparison_df = run_summary_and_method_selection()
comparison_df.head()
